# %%
import seaborn as sns
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('BlockGroupData.csv')
data.head()
# Out:
#    Unnamed: 0  TotalPop  TPopMargin  UnWgtSampleCtPop  PerCapitaIncome  \
# 0           0      1297         347              65.0          93642.0
# 1           1      1340         211              75.0          97506.0
# 2           2       838         306              47.0         143164.0
# 3           3      1226         277              63.0         120569.0
# 4           4      3598         707             247.0           8189.0
#
#    PerCapIncMargin  MedianHouseholdInc  MedHouseholdIncMargin  MedianAge  \
# 0          28468.0             79118.0                44433.0       43.6
# 1          18142.0            101853.0                48195.0       51.9
# 2          71282.0            141179.0               110682.0       39.2
# 3          36279.0            218333.0               111599.0       39.8
# 4           4893.0            119722.0                53241.0       19.4
#
#    MedianAgeMargin  HousingUnits  HousingUnitsMargin  \
# ...

# %%
TotalPop = sns.boxplot(x='Year', y='TotalPop', data=data)

# %%
data2009 = data[(data.Year == 2009)]
sort09 = data2009.sort_values(['Tract', 'BlockGroup'])

data2010 = data[(data.Year == 2013)]
sort10 = data2010.sort_values(['Tract', 'BlockGroup'])

data2011 = data[(data.Year == 2013)]
sort11 = data2011.sort_values(['Tract', 'BlockGroup'])

data2012 = data[(data.Year == 2013)]
sort12 = data2012.sort_values(['Tract', 'BlockGroup'])

data2013 = data[(data.Year == 2013)]
sort13 = data2013.sort_values(['Tract', 'BlockGroup'])

# %%
x = 0
for index, row in sort13.iterrows():
    try:
        sort10.iloc[x,1] = np.interp(1, (0,4), (sort09.iloc[x,1],row['TotalPop']))
        sort10.iloc[x,2] = np.interp(1, (0,4), (sort09.iloc[x,2],row['TPopMargin']))
        sort10.iloc[x,3] = np.interp(1, (0,4), (sort09.iloc[x,3],row['UnWgtSampleCtPop']))
        sort10.iloc[x,4] = np.interp(1, (0,4), (sort09.iloc[x,4],row['PerCapitaIncome']))
        sort10.iloc[x,5] = np.interp(1, (0,4), (sort09.iloc[x,5],row['PerCapIncMargin']))
        sort10.iloc[x,6] = np.interp(1, (0,4), (sort09.iloc[x,6],row['MedianHouseholdInc']))
        sort10.iloc[x,7] = np.interp(1, (0,4), (sort09.iloc[x,7],row['MedHouseholdIncMargin']))
        sort10.iloc[x,8] = np.interp(1, (0,4), (sort09.iloc[x,8],row['MedianAge']))
        sort10.iloc[x,9] = np.interp(1, (0,4), (sort09.iloc[x,9],row['MedianAgeMargin']))
        sort10.iloc[x,10] = np.interp(1, (0,4), (sort09.iloc[x,10],row['HousingUnits']))
        sort10.iloc[x,11] = np.interp(1, (0,4), (sort09.iloc[x,11],row['HousingUnitsMargin']))
        sort10.iloc[x,12] = np.interp(1, (0,4), (sort09.iloc[x,12],row['UnweightedSampleHousingUnits']))
        sort10.iloc[x,17] = 2010
    
        sort11.iloc[x,1] = np.interp(2, (0,4), (sort09.iloc[x,1],row['TotalPop']))
        sort11.iloc[x,2] = np.interp(2, (0,4), (sort09.iloc[x,2],row['TPopMargin']))
        sort11.iloc[x,3] = np.interp(2, (0,4), (sort09.iloc[x,3],row['UnWgtSampleCtPop']))
        sort11.iloc[x,4] = np.interp(2, (0,4), (sort09.iloc[x,4],row['PerCapitaIncome']))
        sort11.iloc[x,5] = np.interp(2, (0,4), (sort09.iloc[x,5],row['PerCapIncMargin']))
        sort11.iloc[x,6] = np.interp(2, (0,4), (sort09.iloc[x,6],row['MedianHouseholdInc']))
        sort11.iloc[x,7] = np.interp(2, (0,4), (sort09.iloc[x,7],row['MedHouseholdIncMargin']))
        sort11.iloc[x,8] = np.interp(2, (0,4), (sort09.iloc[x,8],row['MedianAge']))
        sort11.iloc[x,9] = np.interp(2, (0,4), (sort09.iloc[x,9],row['MedianAgeMargin']))
        sort11.iloc[x,10] = np.interp(2, (0,4), (sort09.iloc[x,10],row['HousingUnits']))
        sort11.iloc[x,11] = np.interp(2, (0,4), (sort09.iloc[x,11],row['HousingUnitsMargin']))
        sort11.iloc[x,12] = np.interp(2, (0,4), (sort09.iloc[x,12],row['UnweightedSampleHousingUnits']))
        sort11.iloc[x,17] = 2011
        
        sort12.iloc[x,1] = np.interp(3, (0,4), (sort09.iloc[x,1],row['TotalPop']))
        sort12.iloc[x,2] = np.interp(3, (0,4), (sort09.iloc[x,2],row['TPopMargin']))
        sort12.iloc[x,3] = np.interp(3, (0,4), (sort09.iloc[x,3],row['UnWgtSampleCtPop']))
        sort12.iloc[x,4] = np.interp(3, (0,4), (sort09.iloc[x,4],row['PerCapitaIncome']))
        sort12.iloc[x,5] = np.interp(3, (0,4), (sort09.iloc[x,5],row['PerCapIncMargin']))
        sort12.iloc[x,6] = np.interp(3, (0,4), (sort09.iloc[x,6],row['MedianHouseholdInc']))
        sort12.iloc[x,7] = np.interp(3, (0,4), (sort09.iloc[x,7],row['MedHouseholdIncMargin']))
        sort12.iloc[x,8] = np.interp(3, (0,4), (sort09.iloc[x,8],row['MedianAge']))
        sort12.iloc[x,9] = np.interp(3, (0,4), (sort09.iloc[x,9],row['MedianAgeMargin']))
        sort12.iloc[x,10] = np.interp(3, (0,4), (sort09.iloc[x,10],row['HousingUnits']))
        sort12.iloc[x,11] = np.interp(3, (0,4), (sort09.iloc[x,11],row['HousingUnitsMargin']))
        sort12.iloc[x,12] = np.interp(3, (0,4), (sort09.iloc[x,12],row['UnweightedSampleHousingUnits']))
        sort12.iloc[x,17] = 2012
    except:
        print("Reached except block")
    finally:
        x = x+1
# Out:
# Reached except block
# Reached except block
# Reached except block
# Reached except block
# Reached except block
# Reached except block
# Reached except block
# Reached except block
# Reached except block
# Reached except block
# Reached except block
# Reached except block
# Reached except block
# Reached except block
# Reached except block
# Reached except block
# Reached except block

# %%
frames = [data, sort10, sort11, sort12]
df_bg = pd.concat(frames)

# %%
df_bg.head()
# Out:
#    Unnamed: 0  TotalPop  TPopMargin  UnWgtSampleCtPop  PerCapitaIncome  \
# 0           0    1297.0       347.0              65.0          93642.0
# 1           1    1340.0       211.0              75.0          97506.0
# 2           2     838.0       306.0              47.0         143164.0
# 3           3    1226.0       277.0              63.0         120569.0
# 4           4    3598.0       707.0             247.0           8189.0
#
#    PerCapIncMargin  MedianHouseholdInc  MedHouseholdIncMargin  MedianAge  \
# 0          28468.0             79118.0                44433.0       43.6
# 1          18142.0            101853.0                48195.0       51.9
# 2          71282.0            141179.0               110682.0       39.2
# 3          36279.0            218333.0               111599.0       39.8
# 4           4893.0            119722.0                53241.0       19.4
#
#    MedianAgeMargin  HousingUnits  HousingUnitsMargin  \
# ...

# %%
del df_bg['Unnamed: 0']

# %%
df_bg.head()
# Out:
#    TotalPop  TPopMargin  UnWgtSampleCtPop  PerCapitaIncome  PerCapIncMargin  \
# 0    1297.0       347.0              65.0          93642.0          28468.0
# 1    1340.0       211.0              75.0          97506.0          18142.0
# 2     838.0       306.0              47.0         143164.0          71282.0
# 3    1226.0       277.0              63.0         120569.0          36279.0
# 4    3598.0       707.0             247.0           8189.0           4893.0
#
#    MedianHouseholdInc  MedHouseholdIncMargin  MedianAge  MedianAgeMargin  \
# 0             79118.0                44433.0       43.6              5.4
# 1            101853.0                48195.0       51.9              6.1
# 2            141179.0               110682.0       39.2              9.4
# 3            218333.0               111599.0       39.8              7.1
# 4            119722.0                53241.0       19.4              0.3
#
# ...

# %%
TotalPop = sns.boxplot(x='Year', y='TotalPop', data=df_bg)

# %%
newData = df_bg[(df_bg.MedianHouseholdInc > 0)]
HouseIncome = sns.boxplot(x='Year', y='MedianHouseholdInc', data=newData)

# %%
newData = df_bg[(df_bg.PerCapitaIncome > 0)]
PerCapitaIncome = sns.boxplot(x='Year', y='PerCapitaIncome', data=newData)

# %%
df_bg.to_csv(r'FinalBlockGroupData.csv')
