# %% [markdown]
# # Import Libraries

# %%
import csv
import datetime
import json
import pandas as pd
import zipfile

# %% [markdown]
# # Import Crime Data

# %% [markdown]
# Import crime data as a ZIP file. Load in as Pandas Dataframe.

# %%
crime_zip = zipfile.ZipFile("C:/Users/Barbieri/DSC-Program/DC-Criminalistics/dc-crime-data/dc-crime-data.csv.zip",
                            mode='r')
crime_csv = crime_zip.open('dc-crime-data.csv')

# %%
crime_df = pd.read_csv(crime_csv)

# %%
crime_df.head()
# Out:
#   NEIGHBORHOOD_CLUSTER  CENSUS_TRACT offensegroup  LONGITUDE  \
# 0            cluster 5        5500.0     property -77.052353
# 1            cluster 4         202.0     property -77.062857
# 2           cluster 17        1804.0      violent -77.027957
# 3           cluster 14        1002.0     property -77.076820
# 4           cluster 23        8904.0     property -76.979941
#
#                   END_DATE         offense-text    SHIFT    YBLOCK  DISTRICT  \
# 0  2009-03-30T15:50:00.000          theft/other  evening  137490.0       2.0
# 1  2009-03-30T16:30:00.000          theft/other  evening  137621.0       2.0
# 2  2009-03-30T00:00:00.000              robbery  evening  143785.0       4.0
# 3  2009-03-30T07:30:00.000  motor vehicle theft  evening  141241.0       2.0
# 4  2009-03-30T20:30:00.000          theft/other  evening  137077.0       5.0
#
#    WARD  ...                                     BLOCK  \
# 0   2.0  ...          2400 - 2499 block of m street nw
# 1   2.0  ...  1224 - 1299 block of wisconsin avenue nw
# 2   4.0  ...    5900 - 5999 block of georgia avenue nw
# 3   3.0  ...     3810 - 3899 block of rodman street nw
# 4   5.0  ...   1600 - 1699 block of maryland avenue ne
#
#                 START_DATE      CCN              OFFENSE  OCTO_RECORD_ID  ANC  \
# 0  2009-03-30T05:30:00.000  9041857          theft/other     09041857-01   2A
# 1  2009-03-30T16:20:00.000  9041858          theft/other     09041858-01   2E
# 2  2009-03-30T17:00:00.000  9041900              robbery     09041900-01   4A
# 3  2009-03-29T07:00:00.000  9041916  motor vehicle theft     09041916-01   3C
# 4  2009-03-30T18:40:00.000  9041927          theft/other     09041927-01   5D
#
#                  REPORT_DAT  METHOD                                location  \
# 0  2009-03-30T20:40:00.000Z  others  38.905263228683658,-77.052355683742746
# 1  2009-03-30T20:34:00.000Z  others  38.906438143434897,-77.062859682010298
# 2  2009-03-30T21:42:00.000Z  others  38.961978891670213,-77.027959395242561
# 3  2009-03-30T22:52:00.000Z  others  38.939039936788873,-77.076822116815663
# 4  2009-03-30T22:40:00.000Z  others  38.901552788657312,-76.979942787227358
#
#     LATITUDE
# 0  38.905255
# 1  38.906430
# 2  38.961971
# 3  38.939032
# 4  38.901545
#
# [5 rows x 29 columns]

# %% [markdown]
# # Import Weather Data

# %% [markdown]
# Import ZIP files and convert weather items to a list of dictionaries.

# %%
weather_zip = zipfile.ZipFile("C:/Users/Barbieri/DSC-Program/DC-Criminalistics/weather-data/crime-weather-data.zip",
                              mode='r')

weather_json = weather_zip.open('crime-weather-data.json')

weather_dict = json.load(weather_json)

# %% [markdown]
# Move items stored in "currently" key up one level. Delete the "currently" key afterwards.

# %%
for w_dict in weather_dict:
    for w_entry in list(w_dict.items()):
        if w_entry[0] == 'currently':
            for ll_entry in w_entry[1].items():
                w_dict[ll_entry[0]] = ll_entry[1]

            del w_dict['currently']

# %% [markdown]
# Load as Pandas Dataframe.

# %%
weather_df = pd.DataFrame(weather_dict)

# %%
weather_df.head()
# Out:
#    apparentTemperature  cloudCover  code  dewPoint error  humidity       icon  \
# 0                43.43        1.00   NaN     30.60   NaN      0.54     cloudy
# 1                57.10        0.17   NaN     29.94   NaN      0.35  clear-day
# 2                56.44        0.12   NaN     30.33   NaN      0.37  clear-day
# 3                47.90        1.00   NaN     47.40   NaN      0.98        fog
# 4                55.91        0.06   NaN     30.21   NaN      0.37  clear-day
#
#     latitude  longitude  precipIntensity  ...  precipType pressure   summary  \
# 0  38.905255 -77.052353           0.0000  ...         NaN  1005.88  Overcast
# 1  38.906430 -77.062857           0.0000  ...         NaN  1012.76     Clear
# 2  38.961971 -77.027957           0.0000  ...         NaN  1012.90     Clear
# 3  38.939032 -77.076820           0.0019  ...        rain   999.52     Foggy
# 4  38.901545 -76.979941           0.0000  ...         NaN  1014.33     Clear
#
#   temperature          time  uvIndex  visibility  windBearing  windGust  \
# 0       46.54  1.238405e+09      0.0        6.28        294.0     15.25
# 1       57.10  1.238444e+09      3.0        5.15        311.0     19.51
# 2       56.44  1.238447e+09      2.0        4.79        308.0     18.43
# 3       47.90  1.238324e+09      0.0        1.18         65.0      2.65
# 4       55.91  1.238453e+09      0.0        4.71        313.0     16.67
#
#    windSpeed
# 0       6.22
# 1       8.43
# 2       8.11
# 3       0.72
# 4       7.44
#
# [5 rows x 21 columns]

# %% [markdown]
# # Merge Crime and Weather Data

# %% [markdown]
# ### Compare Dataframes
#
# Notice that there are 1014 more instances in the crime data than the weather data. This is likely due to (1) change in underlying crime data used for this analysis, (2) data connection error while compiling from Dark Sky API, (3) No data available from Dark Sky API.

# %%
weather_df_len = len(weather_df)
crime_df_len = len(crime_df)

print(weather_df_len, crime_df_len, weather_df_len-crime_df_len)
# Out:
# 380053 381067 -1014

# %% [markdown]
# ### Clean Weather Data
#
# Remove negative time values.

# %%
weather_df = weather_df[weather_df['time'] > 0]

# %% [markdown]
# Convert time value to format used by crime data.

# %%
def converttime(row):
    time = datetime.datetime.fromtimestamp(row).strftime('%Y-%m-%dT%H:%M:%S.000')

    return time

# %%
weather_df['c_time'] = weather_df['time'].apply(converttime)

# %% [markdown]
# ### Merge Crime and Weather

# %%
crime_weather_merge = crime_df.merge(weather_df,
                                     how='left',
                                     left_on=['LATITUDE','LONGITUDE','START_DATE'],
                                     right_on=['latitude','longitude','c_time'])

# %%
crime_weather_merge.head()
# Out:
#   NEIGHBORHOOD_CLUSTER  CENSUS_TRACT offensegroup  LONGITUDE  \
# 0            cluster 5        5500.0     property -77.052353
# 1            cluster 4         202.0     property -77.062857
# 2           cluster 17        1804.0      violent -77.027957
# 3           cluster 14        1002.0     property -77.076820
# 4           cluster 23        8904.0     property -76.979941
#
#                   END_DATE         offense-text    SHIFT    YBLOCK  DISTRICT  \
# 0  2009-03-30T15:50:00.000          theft/other  evening  137490.0       2.0
# 1  2009-03-30T16:30:00.000          theft/other  evening  137621.0       2.0
# 2  2009-03-30T00:00:00.000              robbery  evening  143785.0       4.0
# 3  2009-03-30T07:30:00.000  motor vehicle theft  evening  141241.0       2.0
# 4  2009-03-30T20:30:00.000          theft/other  evening  137077.0       5.0
#
#    WARD  ...  pressure   summary temperature          time  uvIndex  \
# 0   2.0  ...   1005.88  Overcast       46.54  1.238405e+09      0.0
# 1   2.0  ...   1012.76     Clear       57.10  1.238444e+09      3.0
# 2   4.0  ...   1012.90     Clear       56.44  1.238447e+09      2.0
# 3   3.0  ...    999.52     Foggy       47.90  1.238324e+09      0.0
# 4   5.0  ...   1014.33     Clear       55.91  1.238453e+09      0.0
#
#    visibility windBearing windGust  windSpeed                   c_time
# 0        6.28       294.0    15.25       6.22  2009-03-30T05:30:00.000
# 1        5.15       311.0    19.51       8.43  2009-03-30T16:20:00.000
# 2        4.79       308.0    18.43       8.11  2009-03-30T17:00:00.000
# 3        1.18        65.0     2.65       0.72  2009-03-29T07:00:00.000
# 4        4.71       313.0    16.67       7.44  2009-03-30T18:40:00.000
#
# [5 rows x 51 columns]
