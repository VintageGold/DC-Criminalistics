# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Create dataframe for each year's csv of crime data from DC Open Data
# Source link for 2018: http://opendata.dc.gov/datasets/crime-incidents-in-2018
df_dc_2009 = pd.read_csv('Crime_Incidents_in_2009.csv')
df_dc_2010 = pd.read_csv('Crime_Incidents_in_2010.csv')
df_dc_2011 = pd.read_csv('Crime_Incidents_in_2011.csv')
df_dc_2012 = pd.read_csv('Crime_Incidents_in_2012.csv')
df_dc_2013 = pd.read_csv('Crime_Incidents_in_2013.csv')
df_dc_2014 = pd.read_csv('Crime_Incidents_in_2014.csv')
df_dc_2015 = pd.read_csv('Crime_Incidents_in_2015.csv')
df_dc_2016 = pd.read_csv('Crime_Incidents_in_2016.csv')
df_dc_2017 = pd.read_csv('Crime_Incidents_in_2017.csv')
df_dc_2018 = pd.read_csv('Crime_Incidents_in_2018.csv')

# %%
# Check headings and data
# Can quickly see that BID contains nulls and is therefore likely not useful for us
# We'll keep it for now though
df_dc_2009.head()
# Out:
#            X          Y      CCN                REPORT_DAT     SHIFT  METHOD  \
# 0 -76.999518  38.904689   162302  2009-11-12T18:00:00.000Z   EVENING  OTHERS
# 1 -77.022949  38.917236   174072  2009-12-06T23:30:00.000Z  MIDNIGHT  OTHERS
# 2 -77.021912  38.919497  2001387  2009-10-20T08:59:00.000Z       DAY  OTHERS
# 3 -77.021920  38.907912  5147017  2009-10-20T09:32:00.000Z       DAY   KNIFE
# 4 -76.965694  38.853003  6165160  2009-11-18T10:44:00.000Z       DAY  OTHERS
#
#                       OFFENSE                                   BLOCK  \
# 0         MOTOR VEHICLE THEFT      1100 - 1199 BLOCK OF 5TH STREET NE
# 1                THEFT F/AUTO      2000 - 2099 BLOCK OF 8TH STREET NW
# 2                 THEFT/OTHER  2200 - 2299 BLOCK OF GEORGIA AVENUE NW
# 3  ASSAULT W/DANGEROUS WEAPON      1300 - 1399 BLOCK OF 7TH STREET NW
# 4         MOTOR VEHICLE THEFT     2966 - 3031 BLOCK OF 30TH STREET SE
#
#      XBLOCK    YBLOCK       ...        BLOCK_GROUP CENSUS_TRACT  \
# ...

# %%
# Check headings and data. Data from 2009 and 2018 have the same headers.
# This should mean we can put all csvs together into one dataframe
df_dc_2018.head()
# Out:
#            X          Y       CCN                REPORT_DAT SHIFT  METHOD  \
# 0 -76.960110  38.929158  18219944  2018-12-28T10:01:32.000Z   DAY  OTHERS
# 1 -76.936325  38.894457  18219946  2018-12-28T08:32:10.000Z   DAY  OTHERS
# 2 -77.028867  38.895236  18219963  2018-12-28T09:39:49.000Z   DAY  OTHERS
# 3 -77.040307  38.904241  18219967  2018-12-28T10:03:42.000Z   DAY  OTHERS
# 4 -77.028091  38.916289  18219971  2018-12-28T09:54:25.000Z   DAY  OTHERS
#
#                OFFENSE                                        BLOCK    XBLOCK  \
# 0         THEFT F/AUTO      2855 3200  BLOCK OF BLADENSBURG ROAD NE  403459.0
# 1  MOTOR VEHICLE THEFT           4500 - 4699 BLOCK OF DIX STREET NE  405524.0
# 2          THEFT/OTHER  1200 - 1299 BLOCK OF PENNSYLVANIA AVENUE NW  397496.0
# 3          THEFT/OTHER   1100 - 1129 BLOCK OF CONNECTICUT AVENUE NW  396504.0
# 4         THEFT F/AUTO          1900 - 1999 BLOCK OF 12TH STREET NW  397564.0
#
# ...

# %%
df_dc_full = pd.concat([df_dc_2009,df_dc_2010,df_dc_2011,df_dc_2012,df_dc_2013,df_dc_2014,df_dc_2015,df_dc_2016,df_dc_2017,df_dc_2018])

# %%
df_dc_full.head()
# Out:
#            X          Y      CCN                REPORT_DAT     SHIFT  METHOD  \
# 0 -76.999518  38.904689   162302  2009-11-12T18:00:00.000Z   EVENING  OTHERS
# 1 -77.022949  38.917236   174072  2009-12-06T23:30:00.000Z  MIDNIGHT  OTHERS
# 2 -77.021912  38.919497  2001387  2009-10-20T08:59:00.000Z       DAY  OTHERS
# 3 -77.021920  38.907912  5147017  2009-10-20T09:32:00.000Z       DAY   KNIFE
# 4 -76.965694  38.853003  6165160  2009-11-18T10:44:00.000Z       DAY  OTHERS
#
#                       OFFENSE                                   BLOCK  \
# 0         MOTOR VEHICLE THEFT      1100 - 1199 BLOCK OF 5TH STREET NE
# 1                THEFT F/AUTO      2000 - 2099 BLOCK OF 8TH STREET NW
# 2                 THEFT/OTHER  2200 - 2299 BLOCK OF GEORGIA AVENUE NW
# 3  ASSAULT W/DANGEROUS WEAPON      1300 - 1399 BLOCK OF 7TH STREET NW
# 4         MOTOR VEHICLE THEFT     2966 - 3031 BLOCK OF 30TH STREET SE
#
#      XBLOCK    YBLOCK       ...        BLOCK_GROUP CENSUS_TRACT  \
# ...

# %%
# Quick look at full dataset
# Looks like 346,928 observations total - not every observation has every feature (ex: ward, district missing for some observations)
pd.DataFrame.describe(df_dc_full)
# Out:
#                    X              Y           CCN         XBLOCK  \
# count  346928.000000  346928.000000  3.469280e+05  346928.000000
# mean      -77.008154      38.906312  1.370009e+07  399293.539017
# std         0.036298       0.031359  2.845339e+06    3148.138375
# min       -77.113645      38.813478  1.000600e+05  390147.000000
# 25%       -77.031969      38.891416  1.114292e+07  397227.000000
# 50%       -77.013089      38.906444  1.403787e+07  398866.000000
# 75%       -76.985526      38.925404  1.610960e+07  401256.000000
# max       -76.910023      38.994909  9.943899e+07  407806.000000
#
#               YBLOCK           WARD       DISTRICT            PSA  \
# count  346928.000000  346917.000000  346726.000000  346694.000000
# mean   137605.820542       4.439883       3.729380     378.212248
# std      3481.232674       2.367175       1.927187     192.326325
# min    127300.000000       1.000000       1.000000     101.000000
# ...

# %%
# Full list of column names
list(df_dc_full.columns.values)
# Out:
# ['X',
#  'Y',
#  'CCN',
#  'REPORT_DAT',
#  'SHIFT',
#  'METHOD',
#  'OFFENSE',
#  'BLOCK',
#  'XBLOCK',
#  'YBLOCK',
#  'WARD',
#  'ANC',
#  'DISTRICT',
#  'PSA',
#  'NEIGHBORHOOD_CLUSTER',
#  'BLOCK_GROUP',
#  'CENSUS_TRACT',
#  'VOTING_PRECINCT',
#  'LATITUDE',
#  'LONGITUDE',
#  'BID',
#  'START_DATE',
#  'END_DATE',
#  'OBJECTID',
#  'OCTO_RECORD_ID']
